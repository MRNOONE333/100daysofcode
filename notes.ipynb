# %% [markdown]
# cell 1
#
# in code 12 char has size 1 and each string has size 24 no mattrer what even if its a single char.
#
#
# // maybe in future see something which can help in memory saving
#
#
# ![image.png](attachment:image.png)

# %%
cell2 

https://chat.openai.com/share/9de6ee84-c3a0-4871-8909-528f5b0fdf90

difference between the 2-
1.
#include <iostream>
using namespace std;

void swapNums(int x, int y) {
  int z = x;
  x = y;
  y = z;
}

int main() {
  int firstNum = 10;
  int secondNum = 20;

  cout << "Before swap: " << "\n";
  cout << firstNum << secondNum << "\n";

  swapNums(firstNum, secondNum);

  cout << "After swap: " << "\n";
  cout << firstNum << secondNum << "\n";

  return 0;
}


2.
#include <iostream>
using namespace std;

void swapNums(int &x, int &y) {
  int z = x;
  x = y;
  y = z;
}

int main() {
  int firstNum = 10;
  int secondNum = 20;

  cout << "Before swap: " << "\n";
  cout << firstNum << secondNum << "\n";

  swapNums(firstNum, secondNum);

  cout << "After swap: " << "\n";
  cout << firstNum << secondNum << "\n";

  return 0;
}

# %% [markdown]
# cell 3
#
# ![image.png](attachment:image.png)
# img-1

# %% [markdown]
# cell 4
# ![image.png](attachment:image.png)
#
# any of the  syntax can be used to yeild the same result.

# %% [markdown]
# cell - 5
# // Syntax in pointers is is written i a particular way because then it will read the address in that way only , the starting or most significant bit.
# img1-
# ![image-2.png](attachment:image-2.png)
#
#
#
# //  How integer bits are placed in our memory.
# ## Important
# // Also char. will print till there is null char.  SO it will see 65/66 and print the alphabet then it ill stop bcz inn 4 bit  thhere is 0 @ 2,3,4 places.
#
# little/big endian
# img2:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CELL 6
# img 1:
# ![image.png](attachment:image.png)
#
# img2:
# ![image-2.png](attachment:image-2.png)
#
# img 3:
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## cell  - 7
# ![image.png](attachment:image.png)

# %% [markdown]
# ## cell8.
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## cell 9
# ![image.png](attachment:image.png)

# %% [markdown]
# ## cell 10
# ![image.png](attachment:image.png)
